# %% [markdown]
# # kaggle competition-- whale-categorization-playground

# %% [markdown]
# ## Overview of the Steps
# 1. Enable data augmentation, and precompute=True
# 2. Use lr_find() to find highest learning rate where loss is still clearly improving
# 3. Train last layer from precomputed activations for 1-2 epochs
# 4. Train last layer with data augmentation (i.e. precompute=False) for 2-3 epochs with cycle_len=1
# 5. Unfreeze all layers
# 6. Set earlier layers to 3x-10x lower learning rate than next higher layer
# 7. Use lr_find() again
# 8. Train full network with cycle_mult=2 until over-fitting
#
# note in step 4: when pre_compute=True , data augmentation does not work.
# ## simplified flow
# 1. Use lr_find() to find highest learning rate where loss is still clearly improving
# 2. Train last layer with data augmentation (i.e. precompute=False) for 2-3 epochs with cycle_len=1
# 3. Unfreeze all layers
# 4. Set earlier layers to 3x-10x lower learning rate than next higher layer
# 5. Train full network with cycle_mult=2 until over-fitting
#
# ### resize the input size and do it again

# %% [markdown]
# ## 1.preparation and import library

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import torch
from fastai.imports import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.transforms import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %% [markdown]
# ## 2. constant variable and hyper-parameters

# %%
PATH = '/home/paperspace/data/whale-categorization-playground/'

# %%
# !ls {PATH}
# Out:
# sample_submission.csv  test  test.zip  train  train.csv  train.zip

# %%
sz = 224
bs = 24
arch = resnet50

# %%
label_csv = f'{PATH}train.csv'

# %%
n = len(list(open(label_csv)))-1

# %%
n
# Out:
# 9850

# %%
val_idx = get_cv_idxs(n)
val_idx
# Out:
# array([8920, 9839, 1851, ...,  111, 2884, 8774])

# %%
len(val_idx)
# Out:
# 1970

# %% [markdown]
# ## 3. initial exploration

# %%
label_df = pd.read_csv(label_csv)

# %%
label_df.head()
# Out:
#           Image         Id
# 0  00022e1a.jpg  w_e15442c
# 1  000466c4.jpg  w_1287fbc
# 2  00087b01.jpg  w_da2efe0
# 3  001296d5.jpg  w_19e5482
# 4  0014cfdf.jpg  w_f22f3e3

# %%
label_df.pivot_table(index='Id',aggfunc=len).sort_values('Image',ascending=False)[:10]
# Out:
#            Image
# Id
# new_whale    810
# w_1287fbc     34
# w_98baff9     27
# w_7554f44     26
# w_1eafe46     23
# w_fd1cb9d     22
# w_ab4cae2     22
# w_693c9ee     22
# w_987a36f     21
# w_43be268     21

# %%
tfms = tfms_from_model(arch, sz, aug_tfms=transforms_top_down, max_zoom=1.1)

# %%
??tfms_from_stats

# %%
data = ImageClassifierData.from_csv(PATH, 'train', label_csv, bs, tfms, val_idx, test_name='test')

# %%
fn = PATH + data.trn_ds.fnames[0]
fn
# Out:
# '/home/paperspace/data/whale-categorization-playground/train/000466c4.jpg'

# %%
img = PIL.Image.open(fn)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1050x700 at 0x7F514E2EE208>

# %%
img.size
# Out:
# (1050, 700)
